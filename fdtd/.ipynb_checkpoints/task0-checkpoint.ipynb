# %% [markdown]
# Task 0: Simulate a system with magnetic mirror boundary condition (H=0) on one side and electric mirror (E= 0) on the other side. The source is a Gaussian profile propagating to boundaries and back, source located exactly in the center of the simulated domain. The successful presentation should provide a sequence of images as a time evolution (or animation) for electric and magnetic fields. The simulation should finish at the moment where the electric field is vanished (all energy is in the magnetic field)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import animation

import numpy as np
import math as m

nx = 300            #space domain
srcori = int(nx/2)  #location of the source. here, it is at center
srcwid = 5         #source width
srcdel = 10*srcwid        #source delay
nt = nx+srcdel      #time domain

imp0 = 337.0 #impedance

ez = np.zeros(nx)
hy = np.zeros(nx)

fignum = 0

plt.hold(True)

#fignum +=1
#plt.figure(fignum)
#plt.title("Source")
#t = np.arange(0, nt, 1)
#y = np.exp(-((t-srcdel)*(t-srcdel))/(srcwid*srcwid))
#plt.plot(y)
#plt.xlabel("Position")
#plt.ylabel("E-field Amplitude")

#fignum +=1
#plt.figure(fignum)
#plt.plot(np.fft.fft(y))

x = np.arange(0,nx-1,1)
x1 = np.arange(0,nx-1,1)

for dt in range(0,nt):
    hy[x] = hy[x] + (ez[x+1]-ez[x])/imp0
        
    ez[x1] = ez[x1] + (hy[x1]-hy[x1-1])*imp0
        
    ez[srcori] += m.exp(-((dt-srcdel)*(dt-srcdel))/(srcwid*srcwid))

    
    if (dt % 60 == 0 or dt == nt-1):
        fignum += 1
        plt.figure(fignum)
        plt.xlabel("Position")
        plt.ylabel("E-field Amplitude")
        plt.title("E-field at t = "+ str(dt))        
        plt.plot(ez)
        
        if (dt != nt-1):
            plt.plot(hy*imp0)
#        elif (dt == nt-1):
#            fignum+=1
#            plt.figure(fignum)
#            plt.title("FT of E-field at t = "+ str(dt))
#            plt.plot(np.fft.fft(ez))
